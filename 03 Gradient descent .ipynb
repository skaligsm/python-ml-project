# %% [markdown]
#  # Notebook Import and Pakages

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Example 1 --A simple cost function
#
# $$f(x) = x^2+x+1$$

# %%
def f(x):
    return x**2 +x + 2

# %%
#Make Data
x_1 = np.linspace(start=-3,stop=3,num=500)

# %%
#Plot
plt.xlim([-3,3])
plt.ylim(0,8)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives

# %%
def df(x):
    return 2*x+1

# %%
#Plot function and derivative side by side
plt.figure(figsize=[15,5])

# 1 Chart:Cost function
plt.subplot(1,2,1)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)

plt.plot(x_1,f(x_1),color="blue",linewidth=3)

#2 Chart: Derivative
plt.subplot(1,2,2 )

plt.title('Slop of the cost function',fontsize=17)

plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)

plt.grid()

plt.xlim(-2,3)
plt.ylim(-3,6)

plt.plot(x_1,df(x_1 ),color='skyblue',linewidth=5)
plt.show()

# %% [markdown]
#  ## Python Loops & Gradient Descent

# %%
#Python For Loop
for n in range(5):
    print('Hey ..',n)
    
print('End of loop')
# Out:
# Hey .. 0
# Hey .. 1
# Hey .. 2
# Hey .. 3
# Hey .. 4
# End of loop

# %%
#Pythin while loop
n = 0 
while n < 5:
    print('Count..', n)
    n= n + 1
print('End ..')
# Out:
# Count.. 0
# Count.. 1
# Count.. 2
# Count.. 3
# Count.. 4
# End ..

# %%
#Gradient Dascent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slop_list = [df(new_x)]

for n in range(5000):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier *gradient
    
    step_size = abs(new_x-previous_x)
    #print(step_size)
    
    x_list.append(new_x)
    slop_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop run this many times:',n)
        break
    
print('Local minimum occurs at:',new_x)  
print('Slop or df(x) value at this point is',df(new_x))
print('f(x) value or cost at this point is:',f(new_x))
# Out:
# Loop run this many times: 40
# Local minimum occurs at: -0.49962781616118024
# Slop or df(x) value at this point is 0.0007443676776395236
# f(x) value or cost at this point is: 1.75000013852081

# %%
# Super impose the gradient dascent calculations on plot
plt.figure(figsize=[15,5])

# 1 Chart:Cost function
plt.subplot(1,2,1)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)

plt.plot(x_1,f(x_1),color="blue",linewidth=3,alpha=.8)

values = np.array(x_list)
plt.scatter(x_list,f(values), color='red',s=100,alpha=.6)

#2 Chart: Derivative
plt.subplot(1,2,2 )

plt.title('Slop of the cost function',fontsize=17)

plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)

plt.grid()

plt.xlim(-2,3)
plt.ylim(-3,6)

plt.plot(x_1,df(x_1 ),color='skyblue',linewidth=5,alpha= .6)
plt.scatter(x_list,slop_list,color='red',s=100,alpha=.5)
plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Function
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
#Make some data
x_2 = np.linspace(start=-2,stop=2,num=1000)


#Challenge:
def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %%
#Plot function and derivative side by side
plt.figure(figsize=[15,5])

# 1 Chart:Cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)

plt.title('Cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)

plt.plot(x_2,g(x_2),color="blue",linewidth=3)

#2 Chart: Derivative
plt.subplot(1,2,2 )

plt.title('Slop of the cost function',fontsize=17)

plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)

plt.grid()

plt.xlim(-2,2)
plt.ylim(-6,6)

plt.plot(x_2,dg(x_2 ),color='skyblue',linewidth=5)
plt.show()

# %%
#Gradient Dascent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slop_list = [df(new_x)]

for n in range(5000):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier *gradient
    
    step_size = abs(new_x-previous_x)
    #print(step_size)
    
    x_list.append(new_x)
    slop_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop run this many times:',n)
        break
    
print('Local minimum occurs at:',new_x)  
print('Slop or df(x) value at this point is',df(new_x))
print('f(x) value or cost at this point is:',f(new_x))
# Out:
# Loop run this many times: 40
# Local minimum occurs at: -0.49962781616118024
# Slop or df(x) value at this point is 0.0007443676776395236
# f(x) value or cost at this point is: 1.75000013852081

# %% [markdown]
# ## Gradient Dascent as a Python Function

# %%
def gradient_dascent(derivative_func, initial_guess, multiplier = 0.02 ,precision = 0.001 ):

                new_x = initial_guess
                x_list = [new_x]
                slop_list = [derivative_func(new_x)]

                for n in range(5000):
                    previous_x = new_x
                    gradient = derivative_func(previous_x)
                    new_x = previous_x - multiplier *gradient

                    step_size = abs(new_x - previous_x)
                    #print(step_size)

                    x_list.append(new_x)
                    slop_list.append(derivative_func(new_x))

                    if step_size < precision:
                        break
                
        
                return new_x, x_list, slop_list

# %%
local_min, list_x, deriv_list = gradient_dascent(dg,0.5, 0.02,0.001)
print('Local min occurs at:',local_min)
print('Number of steps:',len(list_x))
# Out:
# Local min occurs at: 1.4122375085019094
# Number of steps: 23

# %%
local_min, list_x, deriv_list = gradient_dascent(derivative_func= dg,initial_guess= - 0.1)
print('Local min occurs at:',local_min)
print('Number of steps:',len(list_x))
# Out:
# Local min occurs at: -1.4120887490901561
# Number of steps: 34

# %%
#Calling gradient dascent_function 
local_min, list_x, deriv_list = gradient_dascent(derivative_func= dg,initial_guess= 0.1)
#Plot function and derivative and scatter side by side
plt.figure(figsize=[15,5])

# 1 Chart:Cost function

plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)

plt.title('Cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)

plt.plot(x_2,g(x_2),color="blue",linewidth=3,alpha=  0.8)
plt.scatter(list_x,  g(np.array(list_x), color='red',s=100,alpha=  0.6))
#2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slop of the cost function ',fontsize=17)

plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)

plt.grid()

plt.xlim(-2,2)
plt.ylim(-6,6)

plt.plot(x_2,dg(x_2 ),color='skyblue',linewidth=5)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=.5) 
            
            
plt.show()
# Out:
#   File "C:\Users\sksab\AppData\Local\Temp/ipykernel_7176/3089357828.py", line 20
#     plt.subplot(1, 2, 2)
#     ^
# SyntaxError: invalid syntax
